# %%
import pandas as pd
import numpy as np

# ---------- Load & standardize ----------
abs_df = pd.read_csv("/Users/michaelwalker/RDM_Datalab/ABS_2022_CA_allcounties_NAICS2_from_API.csv")
qcew_df = pd.read_csv("/Users/michaelwalker/RDM_Datalab/qcew_county_naics_sector_2022.csv")  # make this later
# Optional TRI facilities (facility-level)
tri = pd.read_csv("/Users/michaelwalker/RDM_Datalab/tri_release_by_county_naics.csv")

# %%
# Standardize FIPS & NAICS2
def zfill_series(s, n): return s.astype(str).str.extract(r"(\d+)", expand=False).fillna("").str.zfill(n)

abs_df["state"]  = zfill_series(abs_df["state"], 2)
abs_df["county"] = zfill_series(abs_df["county"], 3)
abs_df["naics2"] = abs_df["NAICS2022"].astype(str).str[:2]

# %%
# Convert ABS $1k → dollars
for k in ["PAYANN", "RCPPDEMP"]:
    abs_df[k] = pd.to_numeric(abs_df[k], errors="coerce") * 1000

abs_df = abs_df.rename(columns={
    "FIRMPDEMP":"abs_firms",
    "EMP":"abs_emp",
    "PAYANN":"abs_payroll_usd",
    "RCPPDEMP":"abs_receipts_usd"
})
for c in ["abs_firms","abs_emp","abs_payroll_usd","abs_receipts_usd"]:
    abs_df[c] = pd.to_numeric(abs_df[c], errors="coerce")

# %%
# Minimal QCEW standardization (you’ll adapt to your column names)
# Expecting: state_fips, county_fips, naics (2-digit), year, annual_avg_emplvl, total_annual_wages, avg_weekly_wage
qcew_df["state"]  = zfill_series(qcew_df["state_fips"], 2)
qcew_df["county"] = zfill_series(qcew_df["county_fips"], 3)
qcew_df["naics2"] = qcew_df["naics_sector"].astype(str).str[:2]
qcew_df = qcew_df.rename(columns={
    "annual_avg_emplvl":"qcew_emp",
    "total_annual_wages":"qcew_wages_usd",
    "avg_weekly_wage":"qcew_avg_weekly_wage_usd"
})
for c in ["qcew_emp","qcew_wages_usd","qcew_avg_weekly_wage_usd"]:
    qcew_df[c] = pd.to_numeric(qcew_df[c], errors="coerce")

# %%
tri.head(20)
# Out:
#    state                        county  naics2  tri_releases_lbs
# 0     AK        ALEUTIANS EAST BOROUGH      31      1.962770e+05
# 1     AK     ALEUTIANS WEST CENSUS ARE      31      2.816000e+03
# 2     AK     ALEUTIANS WEST CENSUS ARE      42      2.561228e+02
# 3     AK        ANCHORAGE MUNICIPALITY      32      2.550000e+02
# 4     AK        ANCHORAGE MUNICIPALITY      42      1.203838e+04
# 5     AK        ANCHORAGE MUNICIPALITY      92      3.816450e+04
# 6     AK            BETHEL CENSUS AREA      42      7.814500e+02
# 7     AK           BRISTOL BAY BOROUGH      31      1.353800e+04
# 8     AK                DENALI BOROUGH      21      1.834093e+05
# 9     AK                DENALI BOROUGH      22      5.394602e+05
# 10    AK     FAIRBANKS NORTH STAR BORO      21      5.000000e+01
# 11    AK     FAIRBANKS NORTH STAR BORO      32      0.000000e+00
# 12    AK     FAIRBANKS NORTH STAR BORO      42      2.825542e+02
# 13    AK  FAIRBANKS NORTH STAR BOROUGH      21      1.663703e+07
# 14    AK  FAIRBANKS NORTH STAR BOROUGH      22      2.011980e+05
# 15    AK  FAIRBANKS NORTH STAR BOROUGH      32      2.040004e+03
# 16    AK  FAIRBANKS NORTH STAR BOROUGH      42      1.735000e+03
# 17    AK  FAIRBANKS NORTH STAR BOROUGH      92      3.015422e+05
# 18    AK                HAINES BOROUGH      42      3.159000e-02
# 19    AK       JUNEAU CITY AND BOROUGH      21      9.226872e+07

# %%
counties = pd.read_csv("/Users/michaelwalker/RDM_Datalab/simplemaps_uscounties_basicv1.91/uscounties.csv")

# %%
counties.head(20)
# Out:
#             county    county_ascii            county_full  county_fips  \
# 0      Los Angeles     Los Angeles     Los Angeles County         6037
# 1             Cook            Cook            Cook County        17031
# 2           Harris          Harris          Harris County        48201
# 3         Maricopa        Maricopa        Maricopa County         4013
# 4        San Diego       San Diego       San Diego County         6073
# 5           Orange          Orange          Orange County         6059
# 6       Miami-Dade      Miami-Dade      Miami-Dade County        12086
# 7            Kings           Kings           Kings County        36047
# 8           Dallas          Dallas          Dallas County        48113
# 9        Riverside       Riverside       Riverside County         6065
# 10          Queens          Queens          Queens County        36081
# 11           Clark           Clark           Clark County        32003
# 12            King            King            King County        53033
# 13  San Bernardino  San Bernardino  San Bernardino County         6071
# 14         Tarrant         Tarrant         Tarrant County        48439
# 15           Bexar           Bexar           Bexar County        48029
# 16         Broward         Broward         Broward County        12011
# 17     Santa Clara     Santa Clara     Santa Clara County         6085
# 18           Wayne           Wayne           Wayne County        26163
# 19         Alameda         Alameda         Alameda County         6001
#
#    state_id  state_name      lat       lng  population
# 0        CA  California  34.3219 -118.2247     9848406
# 1        IL    Illinois  41.8401  -87.8168     5185812
# 2        TX       Texas  29.8578  -95.3938     4758579
# 3        AZ     Arizona  33.3490 -112.4915     4491987
# 4        CA  California  33.0343 -116.7350     3282782
# 5        CA  California  33.7031 -117.7609     3164063
# 6        FL     Florida  25.6150  -80.5624     2685296
# 7        NY    New York  40.6413  -73.9383     2646306
# 8        TX       Texas  32.7666  -96.7778     2603816
# 9        CA  California  33.7437 -115.9938     2449909
# 10       NY    New York  40.7035  -73.8196     2330124
# 11       NV      Nevada  36.2152 -115.0135     2293764
# 12       WA  Washington  47.4903 -121.8052     2262713
# 13       CA  California  34.8414 -116.1785     2187816
# 14       TX       Texas  32.7719  -97.2911     2135743
# 15       TX       Texas  29.4489  -98.5200     2037344
# 16       FL     Florida  26.1523  -80.4871     1946127
# 17       CA  California  37.2318 -121.6951     1903297
# 18       MI    Michigan  42.2822  -83.2830     1773767
# 19       CA  California  37.6469 -121.8887     1651949

# %%
key_county = ["county"]
tri = tri.merge(counties, on=str.upper(key_county), how="left")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 key_county = ["county"]
# ----> 2 tri = tri.merge(counties, on=str.upper(key_county), how="left")
#
# TypeError: descriptor 'upper' for 'str' objects doesn't apply to a 'list' object

# %%
mask = tri["county"] == "LOS ANGELES"
tri[mask].head(20)
# Out:
#     state       county  naics2  tri_releases_lbs county_ascii_x county_full_x  \
# 416    CA  LOS ANGELES      22      1.798650e+03            NaN           NaN
# 417    CA  LOS ANGELES      31      1.979277e+05            NaN           NaN
# 418    CA  LOS ANGELES      32      5.182203e+06            NaN           NaN
# 419    CA  LOS ANGELES      33      3.215156e+06            NaN           NaN
# 420    CA  LOS ANGELES      42      5.993930e+04            NaN           NaN
# 421    CA  LOS ANGELES      56      1.133649e+05            NaN           NaN
# 422    CA  LOS ANGELES      92      7.565602e+03            NaN           NaN
#
#      county_fips_x state_id_x state_name_x  lat_x  lng_x  population_x  \
# 416            NaN        NaN          NaN    NaN    NaN           NaN
# 417            NaN        NaN          NaN    NaN    NaN           NaN
# 418            NaN        NaN          NaN    NaN    NaN           NaN
# 419            NaN        NaN          NaN    NaN    NaN           NaN
# 420            NaN        NaN          NaN    NaN    NaN           NaN
# 421            NaN        NaN          NaN    NaN    NaN           NaN
# 422            NaN        NaN          NaN    NaN    NaN           NaN
#
#     county_ascii_y county_full_y  county_fips_y state_id_y state_name_y  \
# 416            NaN           NaN            NaN        NaN          NaN
# 417            NaN           NaN            NaN        NaN          NaN
# 418            NaN           NaN            NaN        NaN          NaN
# 419            NaN           NaN            NaN        NaN          NaN
# 420            NaN           NaN            NaN        NaN          NaN
# 421            NaN           NaN            NaN        NaN          NaN
# 422            NaN           NaN            NaN        NaN          NaN
#
#      lat_y  lng_y  population_y
# 416    NaN    NaN           NaN
# 417    NaN    NaN           NaN
# 418    NaN    NaN           NaN
# 419    NaN    NaN           NaN
# 420    NaN    NaN           NaN
# 421    NaN    NaN           NaN
# 422    NaN    NaN           NaN

# %% [raw]
# # TRI aggregation to county × NAICS2
# tri["state"]  = zfill_series(tri["FIPS_STATE"], 2)
# tri["county"] = zfill_series(tri["FIPS_COUNTY"], 3)
# tri["naics2"] = tri["PRIMARY_NAICS"].astype(str).str[:2]
# tri_g = (tri.groupby(["state","county","naics2"], as_index=False)["TOTAL_RELEASES_LBS"].sum()
# #            .rename(columns={"TOTAL_RELEASES_LBS":"tri_releases_lbs"}))

# %%
# ---------- Merge ----------
key = ["state","county","naics2"]
merged = (abs_df.merge(qcew_df[[*key,"qcew_emp","qcew_wages_usd","qcew_avg_weekly_wage_usd","year"]],
                       on=key, how="left"))

# %%
# If using TRI:
# merged = merged.merge(tri_g, on=key, how="left")

# %%
# ---------- Derived cross-source metrics ----------
# Wage sanity: annualized wage per employee from QCEW vs ABS payroll/emp
merged["qcew_wage_per_emp_usd"] = np.where(merged["qcew_emp"]>0,
                                           merged["qcew_wages_usd"]/merged["qcew_emp"], np.nan)

merged["abs_wage_per_emp_usd"]  = np.where(merged["abs_emp"]>0,
                                           merged["abs_payroll_usd"]/merged["abs_emp"], np.nan)

merged["abs_receipts_per_firm_usd"] = np.where(merged["abs_firms"]>0,
                                               merged["abs_receipts_usd"]/merged["abs_firms"], np.nan)

# %%
# If TRI present: intensity metrics
# merged["tri_lbs_per_emp"]  = np.where(merged["abs_emp"]>0, merged["tri_releases_lbs"]/merged["abs_emp"], np.nan)
# merged["tri_lbs_per_firm"] = np.where(merged["abs_firms"]>0, merged["tri_releases_lbs"]/merged["abs_firms"], np.nan)

# %%
# ---------- Quality checks ----------
assert merged.duplicated(subset=key).sum() == 0
# Non-negatives where applicable
for c in ["abs_firms","abs_emp","abs_payroll_usd","abs_receipts_usd","qcew_emp","qcew_wages_usd"]:
    if c in merged.columns:
        assert (merged[c].dropna() >= 0).all()

# %%
# Save
merged.to_csv("portfolio_abs_qcew_ca_county_naics2.csv", index=False)
