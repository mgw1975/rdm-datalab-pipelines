# %%
https://apps.bea.gov/api/data/?UserID=290EFCBB-FAEF-4B15-AED6-BBFB7B290205&method=GetParameterValuesFiltered&DataSetName=Regional&TargetParameter=LineCode&TableName=CAGDP2&ResultFormat=JSON

# %%
https://apps.bea.gov/api/data/?UserID=290EFCBB-FAEF-4B15-AED6-BBFB7B290205&method=GetData&datasetname=Regional&TableName=CAGDP2&LineCode=12&Year=2022&GeoFIPS=CA&ResultFormat=JSON

# %%
import os
import time
import requests
import pandas as pd

# %%
BEA_API_KEY = os.getenv("BEA_API_KEY", "290EFCBB-FAEF-4B15-AED6-BBFB7B290205")
BASE_URL = "https://apps.bea.gov/api/data/"

# %%
# 1) Replace the BEA_TO_NAICS2 logic with a helper that also accepts pure 2-digit codes
BEA_GROUP_MAP = {
    "31G": "31",   # Manufacturing group
    "44RT": "44",  # Retail Trade group
    "48TW": "48",  # Transportation & Warehousing group
    "G":  "92",    # Government → NAICS 92 (optional to keep)
}

def bea_to_naics2(code: str) -> str | None:
    """
    Map BEA IndustryClassification to a NAICS2-like code:
    - If it's a 2-digit numeric string (e.g., '23', '51'), return as-is.
    - If it's in the known group map (31G, 44RT, 48TW, G), return mapped.
    - Otherwise, return None (e.g., totals or odd aggregates).
    """
    if not code:
        return None
    code = str(code).strip()
    if code.isdigit() and len(code) == 2:
        return code
    return BEA_GROUP_MAP.get(code)

# 2) In fetch_cagdp2_county_by_linecode(), replace the mapping & drop with:
df["naics2"] = df["industryclassification"].apply(bea_to_naics2)
# keep only rows that mapped to a 2-digit NAICS (or chosen groups)
df = df[df["naics2"].notna()].copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 24
#      21     return BEA_GROUP_MAP.get(code)
#      23 # 2) In fetch_cagdp2_county_by_linecode(), replace the mapping & drop with:
# ---> 24 df["naics2"] = df["industryclassification"].apply(bea_to_naics2)
#      25 # keep only rows that mapped to a 2-digit NAICS (or chosen groups)
#      26 df = df[df["naics2"].notna()].copy()
#
# NameError: name 'df' is not defined

# %%
out = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()

if out.empty:
    # Help yourself debug quickly:
    print("[DEBUG] No rows returned after merging all line codes.")
    print("[DEBUG] Sample of line codes retrieved:", linecodes[:10])
    return out

# If not empty, you should have these columns now:
# ['county_fips', 'geoname', 'industryclassification', 'description', 'year', 'gdp_current_usd', 'naics2']
out_cols = ["county_fips", "naics2", "year", "gdp_current_usd"]
missing = [c for c in out_cols if c not in out.columns]
if missing:
    print("[DEBUG] Missing expected columns:", missing)
    print("[DEBUG] Available columns:", list(out.columns))

# %%
def bea_request(params, timeout=60):
    """Small helper to call the BEA API with error handling."""
    r = requests.get(BASE_URL, params=params, timeout=timeout)
    r.raise_for_status()
    payload = r.json()
    beaapi = payload.get("BEAAPI", {})
    if "Error" in beaapi:
        raise RuntimeError(f"BEA API error: {beaapi['Error']}")
    return beaapi

# %%
def get_linecodes_for_cagdp2():
    """Discover valid LineCodes for CAGDP2 (nominal GDP by county & industry)."""
    params = {
        "UserID": BEA_API_KEY,
        "method": "GetParameterValuesFiltered",
        "DataSetName": "Regional",
        "TargetParameter": "LineCode",
        "TableName": "CAGDP2",
        "ResultFormat": "JSON",
    }
    beaapi = bea_request(params)
    vals = beaapi.get("Results", {}).get("ParamValue", [])
    # Return list of (LineCode, Description)
    out = []
    for v in vals:
        lc = str(v.get("Key", "")).strip()
        desc = v.get("Desc", "").strip()
        if lc:
            out.append((lc, desc))
    return out

# %%
def fetch_cagdp2_county_by_linecode(year: int, linecode: str, geo="COUNTY") -> pd.DataFrame:
    """Fetch nominal GDP for a single LineCode (industry) across counties."""
    params = {
        "UserID": BEA_API_KEY,
        "method": "GetData",
        "datasetname": "Regional",
        "TableName": "CAGDP2",   # nominal/current-dollar GDP
        "LineCode": str(linecode),
        "Year": str(year),
        "GeoFIPS": geo,          # "COUNTY" = all U.S. counties; e.g., "CA" to restrict to California
        "ResultFormat": "JSON",
    }
    beaapi = bea_request(params)
    data = beaapi.get("Results", {}).get("Data", [])
    if not data:
        return pd.DataFrame()
    df = pd.DataFrame(data)
    # Normalize column names and clean
    df.columns = [c.lower() for c in df.columns]
    # Keep county rows (5-digit FIPS)
    df = df[df["geofips"].str.len() == 5].copy()
    # DataValue → numeric current-dollar GDP
    df["gdp_current_usd"] = pd.to_numeric(df["datavalue"].str.replace(",", ""), errors="coerce")
    # Keep useful columns
    df = df[["geofips", "geoname", "industryclassification", "description", "timeperiod", "gdp_current_usd"]]
    df = df.rename(columns={"geofips": "county_fips", "timeperiod": "year"})
    df["year"] = df["year"].astype(int)
    # Map BEA industry code → NAICS2
    df["naics2"] = df["industryclassification"].map(BEA_TO_NAICS2)
    # Drop lines that aren't mapped (e.g., totals or special aggregates)
    df = df[~df["naics2"].isna()].copy()
    return df

# %%
def fetch_cagdp2_all_sectors(year: int, geo="COUNTY", sleep_sec=0.2) -> pd.DataFrame:
    """Fetch all industries (loop over valid LineCodes) for a given year."""
    linecodes = get_linecodes_for_cagdp2()
    frames = []
    for lc, desc in linecodes:
        try:
            df = fetch_cagdp2_county_by_linecode(year, lc, geo=geo)
            if not df.empty:
                frames.append(df)
        except Exception as e:
            # Non-fatal: print and continue with next line code
            print(f"[WARN] LineCode {lc} ({desc}) failed: {e}")
        time.sleep(sleep_sec)  # be nice to the API
    if not frames:
        return pd.DataFrame()
    out = pd.concat(frames, ignore_index=True)
    # Deduplicate just in case
    out = out.drop_duplicates(subset=["county_fips", "naics2", "year", "gdp_current_usd"])
    return out

# %%
if __name__ == "__main__":
    YEAR = 2022

    # A) All U.S. counties
    df_us = fetch_cagdp2_all_sectors(YEAR, geo="COUNTY")

    # (Optional) B) Restrict to California only for testing
    # df_us = fetch_cagdp2_all_sectors(YEAR, geo="CA")

    print(df_us.head())
    print("Rows:", len(df_us), "Unique counties:", df_us['county_fips'].nunique(), "NAICS2:", df_us['naics2'].nunique())

    # Save tidy output for joining with QCEW
    out_cols = ["county_fips", "naics2", "year", "gdp_current_usd"]
    df_us[out_cols].to_csv(f"bea_cagdp2_county_naics2_{YEAR}.csv", index=False)
    print("Wrote:", f"bea_cagdp2_county_naics2_{YEAR}.csv")
# Out:
# [WARN] LineCode 1 ([CAGDP2] Gross Domestic Product (GDP): All industry total) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 10 ([CAGDP2] Gross Domestic Product (GDP): Utilities (22)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 11 ([CAGDP2] Gross Domestic Product (GDP): Construction (23)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 12 ([CAGDP2] Gross Domestic Product (GDP): Manufacturing (31-33)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 13 ([CAGDP2] Gross Domestic Product (GDP): Durable goods manufacturing (321,327-339)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 2 ([CAGDP2] Gross Domestic Product (GDP): Private industries) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 25 ([CAGDP2] Gross Domestic Product (GDP): Nondurable goods manufacturing (311-316,322-326)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 3 ([CAGDP2] Gross Domestic Product (GDP): Agriculture, forestry, fishing and hunting (11)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 34 ([CAGDP2] Gross Domestic Product (GDP): Wholesale trade (42)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 35 ([CAGDP2] Gross Domestic Product (GDP): Retail trade (44-45)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 36 ([CAGDP2] Gross Domestic Product (GDP): Transportation and warehousing (48-49)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 45 ([CAGDP2] Gross Domestic Product (GDP): Information (51)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 50 ([CAGDP2] Gross Domestic Product (GDP): Finance, insurance, real estate, rental, and leasing (52,53)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 51 ([CAGDP2] Gross Domestic Product (GDP): Finance and insurance (52)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 56 ([CAGDP2] Gross Domestic Product (GDP): Real estate and rental and leasing (53)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 59 ([CAGDP2] Gross Domestic Product (GDP): Professional and business services (54,55,56)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 6 ([CAGDP2] Gross Domestic Product (GDP): Mining, quarrying, and oil and gas extraction (21)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 60 ([CAGDP2] Gross Domestic Product (GDP): Professional, scientific, and technical services (54)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 64 ([CAGDP2] Gross Domestic Product (GDP): Management of companies and enterprises (55)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 65 ([CAGDP2] Gross Domestic Product (GDP): Administrative and support and waste management and remediation services (56)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 68 ([CAGDP2] Gross Domestic Product (GDP): Educational services, health care, and social assistance (61,62)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 69 ([CAGDP2] Gross Domestic Product (GDP): Educational services (61)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 70 ([CAGDP2] Gross Domestic Product (GDP): Health care and social assistance (62)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 75 ([CAGDP2] Gross Domestic Product (GDP): Arts, entertainment, recreation, accommodation, and food services (71,72)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 76 ([CAGDP2] Gross Domestic Product (GDP): Arts, entertainment, and recreation (71)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 79 ([CAGDP2] Gross Domestic Product (GDP): Accommodation and food services (72)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 82 ([CAGDP2] Gross Domestic Product (GDP): Other services (except government and government enterprises) (81)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 83 ([CAGDP2] Gross Domestic Product (GDP): Government and government enterprises (92)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 87 ([CAGDP2] Gross Domestic Product (GDP): Natural resources and mining (11,21)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 88 ([CAGDP2] Gross Domestic Product (GDP): Trade (42,44-45)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 89 ([CAGDP2] Gross Domestic Product (GDP): Transportation and utilities (22,48-49)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 90 ([CAGDP2] Gross Domestic Product (GDP): Manufacturing and information (31-33,51)) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 91 ([CAGDP2] Gross Domestic Product (GDP): Private goods-producing industries) failed: "['industryclassification', 'description'] not in index"
# [WARN] LineCode 92 ([CAGDP2] Gross Domestic Product (GDP): Private services-providing industries) failed: "['industryclassification', 'description'] not in index"
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 11
#       7 # (Optional) B) Restrict to California only for testing
#       8 # df_us = fetch_cagdp2_all_sectors(YEAR, geo="CA")
#      10 print(df_us.head())
# ---> 11 print("Rows:", len(df_us), "Unique counties:", df_us['county_fips'].nunique(), "NAICS2:", df_us['naics2'].nunique())
#      13 # Save tidy output for joining with QCEW
#      14 out_cols = ["county_fips", "naics2", "year", "gdp_current_usd"]
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'county_fips'
