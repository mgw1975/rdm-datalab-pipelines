# %%
import geopandas as gpd

gdf = gpd.read_file("/Users/michaelwalker/RDM_Datalab/rdm-datalab-pipelines/data_raw_reference/tl_2023_us_county.dbf")
gdf.to_csv("/Users/michaelwalker/RDM_Datalab/rdm-datalab-pipelines/data_raw_reference/tl_2023_us_county.dbfounty_fips.csv", index=False)
